# %% [markdown]
# ### This dataset has the information about tv shows and movies available on Netflix till 2021

# %% [markdown]
# ### This dataset is collected from kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading data

data=pd.read_csv(r"D:\Study\Data Analytics Resources+Projects\Data Analytics Project\Python\Netlfix.csv")

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head()          #To show the top 5 rows.
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.tail()     #It will show you bottom 5 rows
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape   #it will show you number of rows and columns
# Out:
# (7789, 11)

# %%
data.size    #it will show you total elements in a dataset.
# Out:
# 85679

# %%
data.dtypes   #it will show you datatypes.
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()      #it will give you info about number of rows, columns and  dataypes and not null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
data.columns  #it will show you column name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # Finding duplicates value and removing it

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data=data.drop_duplicates()     #removing duplicates

# %%
data.shape   #two duplicate rows has been removed.
# Out:
# (7787, 11)

# %% [markdown]
# # Finding missing values and handling it and show it with the heatmap

# %%
data.isnull()    #it will show you in boolean form null value return True.
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()    #it will give you sum of all null value according to columns
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# ### To use the heatmap we have to import the seaborn library

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #### Ques-1: Find the Show Id and Director of the 'House of Cards'.

# %%
data[data['Title'].isin(["House of Cards"])]     #by using this you can see all the columns of House of cards.
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data['Title']=='House of Cards'][['Title','Show_Id','Director']]    #by using this you can only see only SHow_Id and Director.
# Out:
#                Title Show_Id  \
# 2832  House of Cards   s2833
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# #### Que-2: By using Bar Graph show in which year highest number of Tv shows and movies were released.

# %%
data['Release_Date']
# Out:
# 0          August 14, 2020
# 1        December 23, 2016
# 2        December 20, 2018
# 3        November 16, 2017
# 4          January 1, 2020
#                ...
# 7784      October 19, 2020
# 7785         March 2, 2019
# 7786    September 25, 2020
# 7787      October 31, 2020
# 7788         March 1, 2020
# Name: Release_Date, Length: 7787, dtype: object

# %%
#change its datatype from object to dateTime
data['Release_Date']=pd.to_datetime(data['Release_Date'],format="mixed")

# %%
data['Release_Date'].dt.year.value_counts().nlargest(1)    #
# Out:
# Release_Date
# 2019.0    2153
# Name: count, dtype: int64

# %%
#creating bar graph

data['Release_Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Release_Date'>

# %% [markdown]
# #### Que:3- By using bar graph show how many movies and tv shows are there.

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
ax=sns.countplot(x='Category', data=data)

for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# #### Que:4- Show all the movies that were released in the year 2019.

# %%
data['Year']=data['Release_Date'].dt.year

# %%
data.head(2)

# %%
data[(data['Category']=='Movie')&(data['Year']==2019)]
# Out:
#      Show_Id Category                     Title  \
# 7         s8    Movie                       187
# 8         s9    Movie                       706
# 13       s14    Movie                     2,215
# 15       s16    Movie                    Oct-01
# 18       s19    Movie                    15-Aug
# ...      ...      ...                       ...
# 7771   s7770    Movie  Zindagi Na Milegi Dobara
# 7775   s7774    Movie            Zoé: Panoramas
# 7776   s7775    Movie                    Zodiac
# 7780   s7779    Movie                Zombieland
# 7785   s7784    Movie                    Zubaan
#
#                                    Director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7771                            Zoya Akhtar
# ...

# %% [markdown]
# #### Que-5: SHow only the title of all TV shows that were released in India.

# %%
data[(data['Category']=='TV Show')&(data['Country']=='India')][['Title','Country']]
# Out:
#                                    Title Country
# 86          21 Sarfarosh: Saragarhi 1897   India
# 132                            7 (Seven)   India
# 340                         Agent Raghav   India
# 364                         Akbar Birbal   India
# 533                  Anjaan: Rural Myths   India
# ...                                  ...     ...
# 6249                The Creative Indians   India
# 6400  The Golden Years with Javed Akhtar   India
# 6469              The House That Made Me   India
# 7294                          Typewriter   India
# 7705                     Yeh Meri Family   India
#
# [71 rows x 2 columns]

# %% [markdown]
# #### Que-6: Show top 10 directors, who gave the highest numbers of TV shows and Movies on Netflix.

# %%
data['Director'].value_counts().head(10)

#data['Director'].value_counts().nlargest(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# #### Que-7: Show all the records where category is Movie and type is comedy or country is united kingdom.

# %%
data[(data['Category']=='Movie')&(data['Type']=='Comedies')|(data['Country']=='United kingdom')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %% [markdown]
# #### Que-8: In how many movies/shows Tom cruise was cast?

# %%
data['Cast']=data['Cast'].astype(str)   #convert this datatype from object to string

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# #### Que-9: What are the different ratings defined by the netflix?

# %%
data['Rating'].nunique()  #total number of unique ratings
# Out:
# 14

# %%
data['Rating'].unique()    #name of the unique ratings.
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ##### Que-9.1: How many movies got the TV-14 rating in canada?

# %%
#by using lambda functions.

data.apply(lambda data: data['Category']=='Movie' and data['Rating']=='TV-14' and data['Country']=='Canada',axis=1).sum()


#data[data.apply(lambda data: data['Category']=='Movie' and data['Rating']=='TV-14' and data['Country']=='Canada',axis=1)]
# Out:
# 11

# %%
#we can do this by this method also

data[(data['Category']=='Movie')&(data['Rating']=='TV-14')&(data['Country']=='Canada')].shape
# Out:
# (11, 12)

# %% [markdown]
# ##### Que-9.2: How many tv shows got the R rating after 2018?

# %%
#data[data.apply(lambda data: data['Category']=='TV Show' and data['Rating']=='R' and data['Year']>2018, axis=1)]

data.apply(lambda data: data['Category']=='TV Show' and data['Rating']=='R' and data['Year']>2018, axis=1).sum()
# Out:
# 1

# %% [markdown]
# #### Que-10: What is the maximum duration of a Movie/Show on a Netflix?

# %%
#data['Duration']   #there are data in minutes and season so we will first split it.

# %%
data[['Minutes','Units']]=data['Duration'].str.split(' ', expand=True)

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description    Year Minutes    Units
# 0  In a future where the elite inhabit an island ...  2020.0       4  Seasons
# 1  After a devastating earthquake hits Mexico Cit...  2016.0      93      min

# %%
data['Minutes']=pd.to_numeric(data['Minutes'])

# %%
data['Minutes'].max()
# Out:
# 312

# %% [markdown]
# #### Que-11: Which individual country has the highest number of Tv shows?

# %%
data[data['Category']=='TV Show'].Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# #### Que-12: How can we sort the dataset by Year?

# %%
data.sort_values(by='Release_Date', ascending=False).head(2)
# Out:
#      Show_Id Category         Title                          Director  \
# 1673   s1674    Movie   Death of Me               Darren Lynn Bousman
# 5060   s5060    Movie  Radium Girls  Lydia Dean Pilcher, Ginny Mohler
#
#                                                    Cast  \
# 1673  Maggie Q, Luke Hemsworth, Alex Essoe, Ingkarat...
# 5060  Joey King, Abby Quinn, Cara Seymour, Scott She...
#
#                       Country Release_Date Rating Duration  \
# 1673  United States, Thailand   2021-01-16      R   94 min
# 5060            United States   2021-01-16  TV-14  103 min
#
#                             Type  \
# 1673               Horror Movies
# 5060  Dramas, Independent Movies
#
#                                             Description    Year  Minutes  \
# 1673  With no memory of the previous night, a vacati...  2021.0       94
# 5060  When the women at a radium factory begin to fa...  2021.0      103
#
#      Units  Agg_min
# 1673   min      NaN
# 5060   min      NaN
